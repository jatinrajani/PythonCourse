# %% [markdown]
# # Installing Selenium
#
# We're going to use Selenium for Firefox, which means we'll have to install `geckodriver`. You can download it [here](https://github.com/mozilla/geckodriver/releases/). Download the right version for your system, and then unzip it.
#
# You'll need to then move it to the correct path. This module expects you to be running Python 3.X with Anaconda. If you drag geckodriver into your anaconda/bin folder, then you should be all set.

# %% [markdown]
# # Selenium
#
# Very helpful documentation on how to navigate a webpage with selenium can be found [here](http://selenium-python.readthedocs.io/navigating.html). There are a lot of different ways to navigate, so you'll want to refer to this throughout the workshops, as well as when you're working on your own projects in the future.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup

# %% [markdown]
# First we'll set up the (web)driver. This will open up a Firefox window.

# %%
# setup driver
driver = webdriver.Firefox()

# %% [markdown]
# To go to a webpage, we just enter the url as the argument of the `get` method.

# %%
driver.get("http://www.google.com")

# %%
# go to page
#Since using beautiful soup we cannot go to second page,but using selenium we can do so
driver.get("http://loksabhaph.nic.in/Debates/DebateAdvSearch17.aspx")

# %% [markdown]
# ### Lets Search Session

# %% [markdown]
# We can use the method `find_element_by_name` to find an element on the page by its name. An easy way to do this is to inspect the element.

# %%
session=driver.find_element_by_name("ctl00$ContentPlaceHolder1$ddlsession")

# %% [markdown]
# Now if we want to get the different options in this drop down, we can do the same. You'll notice that each name is associated with a unique value. Here since we're getting multiple elements, we'll use `find_elements_by_tag_name`

# %%
# find options in that drop down
session_options = session.find_elements_by_tag_name("option")

print(session_options[1].get_attribute("value"))
print(session_options[1].text)
# Out:
# 1
# XVII-I Session(17th june to 6th August) 2019

# %% [markdown]
# Now we'll make a dictionary associating each name with its value.

# %%
d_options = {option.text.strip(): option.get_attribute("value") for option in session_options if option.get_attribute("value").isdigit()}
print(d_options)
# Out:
# {'XVII-I Session(17th june to 6th August) 2019': '1', 'XVII-II Session(18th Nov to 13th Dec)2019': '2', 'XVII-III Session(31st Jan to 11th Feb)2020 and (2nd Mar to 23rd Mar)2020': '3', 'XVII-IV Session(14th Sep to 23rd Sep)2020': '4'}

# %% [markdown]
# Now we can select a session by using its name and our dictionary. First we'll make our own function using Selenium's `Select`, and then we'll call it on "XVII-IV Session(14th Sep to 23rd Sep)2020".

# %%
session_select = Select(session)
session_select.select_by_value(d_options["XVII-IV Session(14th Sep to 23rd Sep)2020"])

# %%
submit_button=driver.find_element_by_name("ctl00$ContentPlaceHolder1$ddldebtype")
submit_button.click()

# %% [markdown]
# ### Debate Type

# %% [markdown]
# We can do the same as we did above to find the different sessions

# %%
# find the "debate type" drop down
debate_type= driver.find_element_by_name("ctl00$ContentPlaceHolder1$ddldebtype")

# %%
# get options
debate_type_options = debate_type.find_elements_by_tag_name("option")

print(debate_type_options[1].get_attribute("value"))
print(debate_type_options[1].text)
# Out:
# 1
# ADJOURNMENT MOTION

# %%
d_options = {option.text.strip(): option.get_attribute("value") for option in debate_type_options if option.get_attribute("value").isdigit()}
print(d_options)
# Out:
# {'ADJOURNMENT MOTION': '1', 'ANNOUNCEMENT BY THE CHAIR': '2', 'ASSENT TO BILLS': '3', 'BUDGET (GENERAL)': '4', 'BUDGET (STATES)': '5', 'BUSINESS OF HOUSE': '7', 'ELECTION OF SPEAKER/DY. SPEAKER': '58', 'ELECTION TO COMMITTEES/BOARDS': '59', 'EXPULSION FROM MEMBERSHIP OF LOK SABHA': '0', 'FELICITATIONS': '13', 'GOVERNMENT BILLS': '14', 'GOVERNMENT RESOLUTIONS': '16', 'INTRODUCTION OF MINISTERS': '19', 'INTRODUCTION OF PARLIAMENTARY DELEGATIONS': '56', 'LEAVE OF ABSENCE': '20', 'MATTERS UNDER RULE-377': '21', 'MESSAGES FROM PRESIDENT': '23', 'MESSAGES FROM RAJYA SABHA': '24', "MOTION OF THANKS ON THE PRESIDENT'S ADDRESS": '26', 'OATH OR AFFIRMATION': '31', 'OBITUARY REFERENCE': '32', 'OBSERVATION BY THE CHAIR': '33', 'OBSERVENCE OF SILENCE': '65', 'PANEL OF CHAIRMEN': '61', 'PAPERS LAID ON THE TABLE': '34', 'PARLIAMENTARY COMMITTEES': '35', 'POINTS OF ORDER': '37', 'PRESIDENT ADDRESS': '55', "PRIVATE MEMBERS' BILLS": '39', "PRIVATE MEMBERS' RESOLUTIONS": '40', 'QUESTION OF PRIVILEGE': '41', 'REFERENCES IN THE HOUSE': '42', 'RESIGNATION AND VACATION OF SEAT BY MEMBERS': '44', 'RULING BY THE SPEAKER': '63', 'SHORT DURATION DISCUSSIONS (RULE-193)': '45', 'SPECIAL MENTION (ZERO HOUR)': '46', 'STATEMENT BY MINISTER': '47', 'STATEMENT BY PRIME MINISTER': '48', 'STATEMENT REGARDING ORDINANCE': '49', 'STATUTORY RESOLUTION AND GOVERNMENT BILL': '50', 'STATUTORY RESOLUTIONS': '51', 'SUBMISSIONS BY MEMBERS': '52', 'SUSPENSION OF RULE 331': '74', 'UNION BUDGET': '71', 'VALEDICTORY REFERENCE': '53', 'WITHDRAWL OF MEMBER FROM THE HOUSE': '64'}

# %%
debate_type_select = Select(debate_type)
debate_type_select.select_by_value(d_options['UNION BUDGET'])

# %%
submit_button=driver.find_element_by_name("ctl00$ContentPlaceHolder1$ddldebtype")
submit_button.click()

# %% [markdown]
# ### Select the first debate and open it

# %%
# get the html for the table
title = driver.find_element_by_xpath("/html/body/form/div[3]/div[5]/div/div[2]/div/div[3]/table[2]/tbody/tr[2]/td[2]/a")

# %%
title.click()

# %%
driver.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-6997285da071> in <module>
# ----> 1 driver.html
#
# AttributeError: 'WebDriver' object has no attribute 'html'

# %% [markdown]
# To parse the html, we'll use BeautifulSoup.

# %%
# soup-ify
debate_text = BeautifulSoup(driver.page_source, 'lxml')
debate_text
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>
# 	Debate : Loksabha
# </title><link href="../favicon.ico" rel="shortcut icon"/><link href="css/style.css" rel="stylesheet" type="text/css"/><link href="http://fonts.googleapis.com/css?family=Ubuntu:400,300,400italic,500,700" rel="stylesheet" type="text/css"/>
# <!-- Navigation STARTS here-->
# <link href="css/megafish.css" rel="stylesheet" type="text/css"/><link href="../main-css/style.css" rel="stylesheet" type="text/css"/>
# <!-- Navigation Ends here-->
# <!-- font size switcher -->
# <link href="css/css_small.css" media="screen" rel="alternate stylesheet" title="small" type="text/css"/><link href="css/css_bigger.css" media="screen" rel="alternate stylesheet" title="bigger" type="text/css"/><link href="css/fusiaBlack.css" media="screen" rel="alternate stylesheet" title="fusiaBlack" type="text/css"/><link href="css/yelBlack.css" media="screen" rel="alternate stylesheet" title="yelBlack" type="text/css"/><link href="css/yelBlue.css" media="screen" rel="alternate stylesheet" title="yelBlue" type="text/css"/>
# <script language="javascript" src="js/switcher.js" type="text/javascript"></script>
# <script src="http://ajax.googleapis.com/ajax/libs/jquery/1.3.2/jquery.min.js" type="text/javascript"></script>
# <!-- FlexSlider STARTS HERE-->
# <script charset="utf-8" type="text/javascript">
#         $(window).load(function () {
#             $('.flexslider').flexslider({
#                 animation: "slide"
#             });
#             //$('ul.sf-menu').superfish();
#         });
#     </script>
# <!-- FlexSlider ENDS HERE-->
# <!-- clockBox STARTS HERE-->
# <script type="text/javascript">
#
#         function getCurrentIST() {
#             var dte = new Date();
#             dte.setTime(dte.getTime() + (dte.getTimezoneOffset() + 330) * 60 * 1000);
#             nhour1 = dte.getHours();
#             nmin1 = dte.getMinutes();
#             if (nhour1 == 0) { ap1 = " AM"; nhour1 = 12; }
#             else if (nhour1 <= 11) { ap1 = " AM"; }
#             else if (nhour1 == 12) { ap1 = " PM"; }
#             else if (nhour1 >= 13) { ap1 = " PM"; nhour1 -= 12; }
#             if (nmin1 <= 9) { nmin1 = "0" + nmin1; }
#             document.getElementById('clockbox1').innerHTML = "" + nhour1 + ":" + nmin1 + ap1 + "";
#             setTimeout("getCurrentIST()", 1000);
#         }
#
#         function GetClock() {
#             d = new Date();
#             nhour = d.getHours();
#             nmin = d.getMinutes();
#             if (nhour == 0) { ap = " AM"; nhour = 12; }
#             else if (nhour <= 11) { ap = " AM"; }
#             else if (nhour == 12) { ap = " PM"; }
#             else if (nhour >= 13) { ap = " PM"; nhour -= 12; }
#             if (nmin <= 9) { nmin = "0" + nmin; }
#             document.getElementById('clockbox2').innerHTML = "" + nhour + ":" + nmin + ap + "";
#             setTimeout("getCurrentIST()", 1000);
#             setTimeout("GetClock()", 1000);
#         }
#         window.onload = GetClock;
#
#         $(document).ready(function () {
#             $('input[type="text"]').keypress(function (event) {
#                 if (event.keyCode == '13') { //jquery normalizes the keycode
#
#                     event.preventDefault(); //avoids default action
#                     $(this).parent().find('input[type="submit"]').trigger('click');
#                     // or $(this).closest('form').submit();
#                 }
#             });
#         });
#
#     </script>
# <!-- clockBox ENDS HERE-->
# <style type="text/css">
#         .ActiveMenu
#         {
#             font: bold 12px/17px arial;
#         }
#     </style>
# <script type="text/javascript">
#
#
#
#         function ActiveLoad() {
#
#             if (window.location.href.indexOf("debatelok.aspx") > -1) {
#
#                 $(document).ready(function () {
#                     $('#lsdebates').addClass('ActiveMenu');
#
#                 });
#             }
#             else if (window.location.href.indexOf("debateint.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#internetdebates').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("debatelanguage.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#debatelang').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("debatespeech.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#debatespeech').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("debatecopyright.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#copyright').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("Synopsis.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#debSynopsis').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("uncorrecteddebate.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#debUnCor').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("textofdebate.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#debTextofDeb').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("hindifonts.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#debHindiFonts').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("disclaimer.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#debDisclaimer').addClass('ActiveMenu');
#                 });
#             }
#             else if ((window.location.href.indexOf("DebateAdvSearch16.aspx") > -1)
#             || (window.location.href.indexOf("DebMemberSearch.aspx") > -1)
#             || (window.location.href.indexOf("DebMemberSearch14.aspx") > -1)
#             || (window.location.href.indexOf("DebSubjectSearch_freeText.aspx") > -1)
#             || (window.location.href.indexOf("DebSubjectSearch_freeText14.aspx") > -1)
#             || (window.location.href.indexOf("Result12.aspx") > -1)
#             || (window.location.href.indexOf("Result13.aspx") > -1)
#             || (window.location.href.indexOf("Result14.aspx") > -1)
#             || (window.location.href.indexOf("Result15.aspx") > -1)
#             || (window.location.href.indexOf("Result16.aspx") > -1)
#
#             ) {
#                 $(document).ready(function () {
#                     $('#debSearch').addClass('ActiveMenu');
#                     $('ul.sub_menu li a#subDebSearch').addClass('active');
#                 });
#             }
#             else if (window.location.href.indexOf("withhumour.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#debWitHumour').addClass('ActiveMenu');
#                 });
#
#             }
#             else if ((window.location.href.indexOf("Debatetextsearch16.aspx") > -1)) {
#                 $(document).ready(function () {
#                     $('#debSearchsubwise').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("DebMembersearch16.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#debSearchmemwise').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("cdate_nls.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#debSearchdatewise').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("DebateArchive.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#debarchive').addClass('ActiveMenu');
#                 });
#             }
#
#             else if (window.location.href.indexOf("DebateAdvSearch15.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#Ar15').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("DebateAdvSearch14.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#Ar14').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("DebateAdvSearch13.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#Ar13').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("DebateAdvSearch12.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#Ar12').addClass('ActiveMenu');
#                 });
#             }
#             else if (window.location.href.indexOf("ls11.aspx") > -1) {
#                 $(document).ready(function () {
#                     $('#Ar11').addClass('ActiveMenu');
#                 });
#             }
#
#
#
#         }
#     </script>
# <!-- For Special Character Block Start  -->
# <script src="../js/Global_Search_Validation.js" type="text/javascript"></script>
# <!--  For Special Character Block End   -->
# <script language="javascript" type="text/javascript">
#     function PrintElem(elem) {
#         Popup($(elem).html());
#     }
#
#     function Popup(data) {
#         var mywindow = window.open('', '', 'height=400,width=600');
#         mywindow.document.write('<html><head><title></title>');
#         /*optional stylesheet*/ //mywindow.document.write('<link rel="stylesheet" href="main.css" type="text/css" />');
#         mywindow.document.write('</head><body >');
#         mywindow.document.write(data);
#         mywindow.document.write('</body></html>');
#
#         mywindow.print();
#         mywindow.close();
#
#         return true;
#     }
#
#     </script>
# </head>
# <body onload="ActiveLoad()">
# <form action="./Result17.aspx?dbsl=4557" id="form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="EA04AEDF"/>
# <input id="__VIEWSTATEENCRYPTED" name="__VIEWSTATEENCRYPTED" type="hidden" value=""/>
# <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="+P9Ssp3IJ1IKHEfu5pBh63fxf9JiUdmRssk74A41JPd3aoKN1MumEnmV/MfU/s96TM0k5X60A/BqroY1ZBrxQN5GcuQpGocgBu79nOAB0V0bVx52dQaI4v4zzCUNVHWpIALUURAyPNx8iKmkCAjjMsYMnNkK6TQYDypLwnR60vU="/>
# </div>
# <div id="mainContainer">
# <!--top small header-->
# <div id="top-pan">
# <ul class="siteAcces">
# <li><a href="../Screenreaderaccess.aspx">Screen Reader Access</a></li>
# <li><a href="#content" name="content">Skip to Main Content</a></li>
# <li><a href="#nav" name="top">Skip to Navigation</a></li>
# <li>
# <div class="text-size">
# <ul>
# <li>Text Size</li>
# <li><a class="smaller small-tex" href="javascript:chooseStyle('small', 60);" title="Smaller Size">
#                                 A</a></li>
# <li><a class="switch" href="javascript:chooseStyle('none', 60);" title="Default Size">
#                                 A</a></li>
# <li class="big_text"><a class="bigger big-tex" href="javascript:chooseStyle('bigger', 60);" title="Bigger Size">A</a></li>
# </ul>
# </div>
# </li>
# <li>
# <ul class="color-box">
# <li><a href="javascript:chooseStyle('none', 60);" title="Select Default">
# <img alt="Normal Theme" src="images/normal.gif" title="Select Normal Theme"/></a></li>
# <li><a href="javascript:chooseStyle('fusiaBlack', 60);" title="Select fusiaBlack">
# <img alt="Fusia on Black Theme" src="images/fusia.gif" title="Select Fusia on Black Theme"/></a></li>
# <li><a href="javascript:chooseStyle('yelBlue', 60);" title="Select yelBlue">
# <img alt="Yellow on Blue Theme" src="images/blue.gif" title="Select Yellow on Blue Theme"/></a></li>
# <li><a href="javascript:chooseStyle('yelBlack', 60);" title="Select yelBlack">
# <img alt="Yellow on Black Theme" src="images/yellow.gif" title="Select Yellow on Black Theme"/></a></li>
# </ul>
# </li>
# <li class="hindi_lang last"><a href="http://164.100.47.194/Loksabhahindi/Debates/debates.aspx" title="Hindi">हिन्दी मे</a></li>
# </ul>
# </div>
# <!--top small header-->
# <!-- Header Start -->
# <div id="header">
# <div class="header_left logo">
# <img alt="India Emblemb" height="79" src="images/logo.gif" width="53"/>
# <h1>
# <span class="t1">Parliament of India</span> Lok Sabha <span class="t2">House of the
#                         People</span></h1>
# </div>
# <div class="header_right">
# <div class="searchBox">
# <input class="search" id="txtSearchGlobal" name="ctl00$txtSearchGlobal" onkeypress="return IsAlphaNumeric(event);" placeholder="Search" type="text"/>
# <input class="searchBtn" id="btnSearchGlobal" name="ctl00$btnSearchGlobal" onclick="return IsAlphaNumericPast();" type="submit" value="Go"/>
# <br/>
# <span id="error" style="color: Red; display: none">* Special Characters not allowed</span>
# </div>
# <div class="clockBox">
# <div class="clock">
# <object classid="clsid:D27CDB6E-AE6D-11cf-96B8-444553540000" codebase="http://download.macromedia.com/pub/shockwave/cabs/flash/swflash.cab#version=6,0,0,0" style="width: 60px; height: 60px;">
# <param name="movie" value="../images/clock-s.swf"/>
# <param name="quality" value="high"/>
# <param name="wmode" value="transparent"/>
# <param name="menu" value="false"/>
# <embed allowfullscreen="true" allowscriptaccess="always" height="60" menu="false" src="../images/clock-s.swf" type="application/x-shockwave-flash" width="60" wmode="transparent">
# </embed></object>
# </div>
# <p style="padding-bottom: 0px!important; font-size: 1.2em!important;">
# <span class="indtime">India Time</span> <span id="clockbox1" style="color: #01538C;">
# </span>
# <br/>
# <span class="yourtime">Your Time</span> <span id="clockbox2" style="color: #01538C;">
# </span>
# <br/>
#                         Wednesday,
#                         27 January 2021</p>
# </div>
# </div>
# </div>
# <!-- /Header End -->
# <!-- Navigation -->
# <div id="nav">
# <div class="nav">
# <div class="wrapper_nav">
# <ul class="sf-menu topNav" id="example">
# <li><a href="http://loksabha.nic.in" id="Home" title="Home">Home</a></li><li><a href="http://loksabhaph.nic.in/Members/AlphabeticalList.aspx" id="Members" title="Members">Members</a><div class="sf-mega"><div class="sf-mega-section"><h2></h2><ul><li><a href="http://loksabhaph.nic.in/Members/AlphabeticalList.aspx">Sitting Members</a></li><li><a href="http://loksabhaph.nic.in/Members/Memberhomepage.aspx">Members Home Page</a></li><li><a href="http://memberls.nic.in/">Members' Portal</a></li><li><a href="http://loksabhaph.nic.in/Members/membercontactdetails.aspx">Contact Details</a></li><li><a href="http://loksabhaph.nic.in/Members/MemberSearch.aspx">Members Search</a></li><li><a href="http://loksabhaph.nic.in/Members/StatisticalAnalysis.aspx">Statistical Analysis</a></li><li><a href="http://loksabhaph.nic.in/Members/MemberAttendance.aspx">Attendance of Members</a></li><li><a href="http://loksabhaph.nic.in/Members/handbook.aspx">Handbook </a></li><li><a href="http://loksabhaph.nic.in/Members/lokprev.aspx">Members Since 1952</a></li><li><a href="http://loksabhaph.nic.in/Members/MembersDied_Resigned.aspx">Others</a></li></ul></div><div class="sf-mega-section"><img height="162" src="http://loksabhaph.nic.in/writereaddata/menuimages/member-thumb.jpg" width="214"/> </div></div></li><li><a href="http://loksabhaph.nic.in/Business/ListofBusiness.aspx" id="Business" title="Business">Business</a><div class="sf-mega"><div class="sf-mega-section"><h2></h2><ul><li><a href="http://loksabhaph.nic.in/Business/ProvisionalCalendar.aspx">Provisional Calendar</a></li><li><a href="http://loksabhaph.nic.in/Business/ListofBusiness.aspx">List of Business</a></li><li><a href="http://loksabhaph.nic.in/Business/paperlaid.aspx">Papers to be Laid</a></li><li><a href="http://loksabhaph.nic.in/Business/UserPrivateMember.aspx">List of Private Members' Business</a></li><li><a href="http://loksabhaph.nic.in/Business/UserBulletin1.aspx">Bulletin-I</a></li><li><a href="http://loksabhaph.nic.in/Business/UserBulletin2.aspx">Bulletin-II</a></li><li><a href="http://loksabhaph.nic.in/Business/StatementOfWork.aspx">Statement of Work</a></li><li><a href="http://loksabhaph.nic.in/Business/SpecialMentionDeb17.aspx">Special Mentions (ZERO HOUR)</a></li><li><a href="http://loksabhaph.nic.in/Business/ResumeOfWork.aspx">Resume of Work</a></li></ul></div><div class="sf-mega-section"><img height="162" src="http://loksabhaph.nic.in/writereaddata/menuimages/business-thumb.jpg" width="214"/> </div></div></li><li><a href="http://loksabhaph.nic.in/Questions/Qtextsearch.aspx" id="Questions" title="Questions">Questions</a><div class="sf-mega"><div class="sf-mega-section"><h2></h2><ul><li><a href="http://loksabhaph.nic.in/Questions/QuestionsHome.aspx">Home</a></li><li><a href="http://loksabhaph.nic.in/Questions/questionlist.aspx">Question List</a></li><li><a href="http://loksabhaph.nic.in/Questions/QuestionStatus_Home.aspx">Status of notices of question</a></li><li><a href="http://164.100.47.193/provisionalcalender/17/CalendarUploading.pdf">Questions Calendar</a></li><li><a href="http://loksabhaph.nic.in/Questions/GroupingOfMinistries.aspx">Grouping of Ministries - Alphabetical</a></li><li><a href="https://mpa.gov.in/documents/parliament-units-phones">Officers in Min./Dept. Dealing with Parliamentary Work</a></li><li><a href="http://loksabhaph.nic.in/Questions/Qtextsearch.aspx">Question Search</a></li><li><a href="http://loksabhaph.nic.in/Questions/supleadvanceqsearch.aspx">Supplementary Questions</a></li></ul></div><div class="sf-mega-section"><img height="162" src="http://loksabhaph.nic.in/writereaddata/menuimages/question.jpg" width="214"/> </div></div></li><li><a class="active" href="http://loksabhaph.nic.in/Debates/Debatetextsearch16.aspx" id="Debates" title="Debates">Debates</a><div class="sf-mega"><div class="sf-mega-section"><h2></h2><ul><li><a href="http://loksabhaph.nic.in/Debates/debates.aspx">Introduction</a></li><li><a href="http://loksabhaph.nic.in/Debates/Synopsis.aspx">Syn ...
# </li></ul>
# </div>
# </div>
# </div>
# <ul class="sub_menu">
# <li><a href="http://loksabhaph.nic.in/Debates/debates.aspx" id="subIntro" title="Introduction">Introduction</a></li><li><a href="http://loksabhaph.nic.in/Debates/Synopsis.aspx" id="subSynopsis" title="Synopsis">Synopsis</a></li><li><a href="http://loksabhaph.nic.in/Debates/uncorrecteddebate.aspx" id="subUnCorrected" title="Uncorrected Debate">Uncorrected Debate</a></li><li><a href="http://loksabhaph.nic.in/Debates/textofdebate.aspx" id="subTextofDebate" title="Text of Debate">Text of Debate</a></li><li><a href="http://loksabhaph.nic.in/Debates/cadebadvsearch.aspx" id="subCADeabte" title="Constituent Assembly Debates">Constituent Assembly Debates</a></li><li><a href="http://loksabhaph.nic.in/Debates/withhumour.aspx" id="subWitHumour" title="Wit And Humour">Wit And Humour</a></li><li><a href="http://loksabhaph.nic.in/Debates/DebateAdvSearch17.aspx" id="subDebSearch" title="Debate Search">Debate Search</a></li><li><a href="http://loksabhaph.nic.in/Debates/hindifonts.aspx" id="subDebHindifonts" title="Hindi Fonts">Hindi Fonts</a></li><li><a href="http://loksabhaph.nic.in/Debates/disclaimer.aspx" id="subDebDisclaimer" title="Disclaimer">Disclaimer</a></li>
# </ul>
# <!-- /Navigation -->
# <div class="clear">
# </div>
# <!-- left_mid_right_block -->
# <div id="content">
# <div id="left_mid_right_block">
# <div id="pnlLeft">
# <div id="left_block">
# <div id="pnlLft1">
# <div id="pnlDebSearch">
# <div class="sitting_members left_home_section left_home_section1">
# <h6>
#                                         Debate Search</h6>
# <ul>
# <li><a href="http://loksabhaph.nic.in/Debates/DebateAdvSearch17.aspx" id="debSearch" search="" title="Advance">Advance Search</a></li><li><a href="http://loksabhaph.nic.in/Debates/Debatetextsearch16.aspx" id="debSearchsubwise" search="" title="Subject" wise="">Subject wise Search</a></li><li><a href="http://loksabhaph.nic.in/Debates/DebMembersearch16.aspx" id="debSearchmemwise" search="" title="Member" wise="">Member wise Search</a></li><li><a href="http://loksabhaph.nic.in/Debates/cdate_nls.aspx" id="debSearchdatewise" search="" title="Contents-Datewise">Contents-Datewise Search</a></li>
# </ul>
# </div>
# </div>
# <div id="pnlArchive">
# <div class="sitting_members left_home_section left_home_section1">
# <h6>
#                                         Archive</h6>
# <ul>
# <ul>
# <li><a href="http://loksabhaph.nic.in/Debates/Debate_archiveall.aspx" id="Ar16" sabha="" title="Lok">Lok Sabha 12-15</a></li><li><a href="http://loksabhaph.nic.in/Debates/DebMembersearch_archive.aspx" member="" sabha="" search="" title="Lok" wise="">Lok Sabha 12-15 Member Wise Search</a></li><li><a href="http://loksabhaph.nic.in/Debates/DebateAdvSearch16.aspx" id="Ar15" sabha="" title="Lok">Lok Sabha 16</a></li><li><a href="http://loksabhaph.nic.in/Debates/DebateAdvSearch15.aspx" id="Ar15" sabha="" title="Lok">Lok Sabha 15</a></li><li><a href="http://loksabhaph.nic.in/Debates/DebateAdvSearch14.aspx" id="Ar14" sabha="" title="Lok">Lok Sabha 14</a></li><li><a href="http://loksabhaph.nic.in/Debates/DebateAdvSearch13.aspx" id="Ar13" sabha="" title="Lok">Lok Sabha 13</a></li><li><a href="http://loksabhaph.nic.in/Debates/DebateAdvSearch12.aspx" id="Ar12" sabha="" title="Lok">Lok Sabha 12</a></li><li><a href="http://loksabhaph.nic.in/Debates/ls11.aspx" id="Ar11" sabha="" title="Lok">Lok Sabha 11</a></li>
# </ul>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="mid_block">
# <div style="width: 750px !important">
# <div class="bradcumWrap" style="margin-bottom: 5px">
# <ul class="bradumPan">
# <li><a href="http://loksabha.nic.in" title="Home">Home</a></li>
# <li><a href="Debatetextsearch16.aspx" title="Debates">Debates </a></li>
# <li><a href="DebateAdvSearch17.aspx" title="Debate Advance Search 17">Debate Advance
#                     Search 16 </a></li>
# <li>Details</li>
# </ul>
# <ul class="bradumright">
# <li><a href="javascript:void(0)" onclick="history.go(-1)" title="Home">Back</a>
# </li>
# </ul>
# </div>
# </div>
# <table>
# <tbody><tr>
# <td>
# <table align="right" width="100%">
# <tbody><tr align="right">
# <td align="right">
# </td>
# </tr>
# <tr>
# <td style="float: right;">
# <a class="Print" href="javascript:void(0);" onclick="PrintElem('#pnlDiv1')">Print</a>
# </td>
# </tr>
# </tbody></table>
# <br/>
# <div id="pnlDiv1" style="width: 730px;">
# <div style="text-align: center; font-weight: bold;">
# <h5 style="text-decoration: underline;text-align: center;">
#                             Seventeenth Loksabha</h5>
# <div>
# </div>
# <div style="text-align: center;">
# </div>
# <div style="text-align: left;">
# </div>
# </div>
# <br/>
# <div>
#                         &gt;<p></p>
# <p class="MsoNormal" style="margin-left:4.5pt;line-height:150%"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>Title:
#  Combined discussion on the Supplementary Demands for Grant 'First Batch '
# 2020-21 and Demands for excess Grants (2016-17). <span lang="HI"><o:p></o:p></span></span></p>
# <p class="MsoNormal" style="margin-left:4.5pt;line-height:150%"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><a name="3901*1"><b><o:p></o:p></b></a></span></p><a name="3901*1">
# <p class="MsoNormal" style="text-align:justify;line-height:150%"><b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>माननीय</span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'> <b>सभापति</b></span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>: </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>मद संख्या
# </span><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-bidi-font-weight:bold'>16</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'> </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>और </span><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif";mso-bidi-font-weight:bold'>17</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'><span style="mso-spacerun:yes">
# </span></span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;
# font-family:"Utsaah","sans-serif";mso-ansi-font-weight:bold'>अब सभा
# में अनुदानों</span><b style="mso-ansi-font-weight:normal"><span lang="HI" style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'> </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>की अनुपूरक
# मांगों तथा अतिरिक्त
# अनुदानों की मांगों
# को एक साथ चर्चा
# के लिए लिया जाएगा
# । अनुपूरक मांगों
# पर प्रो</span><b style="mso-bidi-font-weight:
# normal"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>.
# </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:
# "Utsaah","sans-serif";mso-ansi-font-weight:bold'>सौगत राय
# जी के चार कटौती
# प्रस्ताव परिचालित
# किए गए हैं ।</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></b></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><span style="mso-spacerun:yes"> </span>(<span lang="HI">व्यवधान)</span><o:p></o:p></span></p>
# <p class="MsoNormal" style="text-align:justify;line-height:150%"><b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>माननीय</span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'> <b>सभापति</b></span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>: </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>यदि
# वह अपने कटौती
# प्रस्ताव प्रस्तुत
# करना चाहते हैं
# तो पन्द्रह मिनट
# के भीतर सभा पटल
# पर पर्ची भेज दें</span><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>, <span lang="HI">जिसमें उन कटौती
# प्रस्तावों की
# संख्याएं लिखी
# हों जिन्हें वह
# प्रस्तुत करना
# चाहते हैं । </span><o:p></o:p></span></p>
# <p class="MsoNormal" style="text-align:justify;text-indent:.5in;line-height:150%"><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>इस
# प्रकार प्रस्तुत
# किए गए कटौती प्रस्ताव
# की क्रम संख्याओं
# को दर्शाने वाली
# सूची कुछ समय के
# पश्चात् सूचना
# पट्ट पर लगा दी
# जाएगी ।</span><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></p>
# <p align="center" class="MsoNormal" style="text-align:center;text-indent:.5in;
# line-height:150%"><span style='font-size:18.0pt;line-height:150%;font-family:
# "Utsaah","sans-serif"'><span style="mso-spacerun:yes"> </span>(<span lang="HI">व्यवधान)</span><o:p></o:p></span></p>
# <p class="MsoNormal" style="text-align:justify;line-height:150%"><b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>माननीय</span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'> <b>सभापति</b></span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>: </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>यदि
# माननीय सदस्यों
# को उस सूची में
# कोई विसंगति मिले
# तो वह उसकी सूचना
# तत्काल सभा पटल
# पर मौजूद अधिकारी
# को दे दें । </span><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><span style="mso-spacerun:yes"> </span>(<span lang="HI">व्यवधान)</span><o:p></o:p></span></p>
# <p class="MsoNormal" style="line-height:150%"><b><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'><o:p> </o:p></span></b></p>
# <p class="MsoNormal" style="line-height:150%"><b><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'><o:p> </o:p></span></b></p>
# <p class="MsoNormal" style="line-height:150%"><b><span lang="HI" style='font-size:
# 18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>माननीय</span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'> <b>सभापति</b></span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>: </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>प्रस्ताव
# प्रस्तुत हुए</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>: <o:p></o:p></span></b></p>
# <p class="MsoNormal" style="margin-top:0in;margin-right:.5in;margin-bottom:10.0pt;
# margin-left:.5in;text-align:justify;tab-stops:1.0in"><span style='font-size:
# 18.0pt;line-height:115%;font-family:"Utsaah","sans-serif"'>“ <span lang="HI">कि
# सिविल मंत्रालयों
# से संबंधित अनुदानों
# की अतिरिक्त मांगों
# की सूची के स्तम्भ</span>
# 2 <span lang="HI">में दर्शाए
# गए मांग शीर्ष
# संख्या</span> 13, 21 <span lang="HI">और</span>
# 23 <span lang="HI">के संबंध में
# </span>31 <span lang="HI">मार्च</span>, 2017 <span lang="HI">को समाप्त होने
# वाले वर्ष में
# संदाय के दौरान
# हुए खर्चों की
# अदायगी करने हेतु
# अनुदानों की अतिरिक्त
# मांगों की सूची
# के स्तंभ</span> 3 <span lang="HI">में
# दर्शायी गयी राजस्व
# लेखा तथा पूंजी
# लेखा संबंधी राशियों
# से अनधिक संबंधित
# अतिरिक्त राशियां
# भारत की संचित
# निधि में से राष्ट्रपति
# को दी जाएं ।</span> ”<o:p></o:p></span></p>
# <span style='font-size:18.0pt;line-height:115%;font-family:"Utsaah","sans-serif";
# mso-fareast-font-family:Calibri;mso-fareast-theme-font:minor-latin;mso-ansi-language:
# EN-US;mso-fareast-language:EN-US;mso-bidi-language:HI'><br clear="all" style="mso-special-character:line-break;page-break-before:always"/>
# </span>
# <p class="MsoNormal"><span style='font-size:18.0pt;line-height:115%;font-family:
# "Utsaah","sans-serif"'><o:p> </o:p></span></p>
# <p class="MsoNormal"><span style='font-size:18.0pt;line-height:115%;font-family:
# "Utsaah","sans-serif";mso-no-proof:yes'><v:shapetype coordsize="21600,21600" filled="f" id="_x0000_t75" o:preferrelative="t" o:spt="75" path="m@4@5l@4@11@9@11@9@5xe" stroked="f">
# <v:stroke joinstyle="miter">
# <v:formulas>
# <v:f eqn="if lineDrawn pixelLineWidth 0">
# <v:f eqn="sum @0 1 0">
# <v:f eqn="sum 0 0 @1">
# <v:f eqn="prod @2 1 2">
# <v:f eqn="prod @3 21600 pixelWidth">
# <v:f eqn="prod @3 21600 pixelHeight">
# <v:f eqn="sum @0 0 1">
# <v:f eqn="prod @6 1 2">
# <v:f eqn="prod @7 21600 pixelWidth">
# <v:f eqn="sum @8 21600 0">
# <v:f eqn="prod @7 21600 pixelHeight">
# <v:f eqn="sum @10 21600 0">
# </v:f></v:f></v:f></v:f></v:f></v:f></v:f></v:f></v:f></v:f></v:f></v:f></v:formulas>
# <v:path gradientshapeok="t" o:connecttype="rect" o:extrusionok="f">
# <o:lock aspectratio="t" v:ext="edit">
# </o:lock></v:path></v:stroke></v:shapetype><v:shape id="Picture_x0020_1" o:spid="_x0000_i1027" style="width:468pt;height:661.5pt;visibility:visible;mso-wrap-style:square" type="#_x0000_t75">
# <v:imagedata o:title="" src="18092020_files/image001.png">
# </v:imagedata></v:shape></span><span style='font-size:18.0pt;line-height:115%;font-family:
# "Utsaah","sans-serif"'><o:p></o:p></span></p>
# <p class="MsoNormal" style="margin-top:0in;margin-right:.5in;margin-bottom:10.0pt;
# margin-left:.5in;text-align:justify;tab-stops:1.0in"><span style='font-size:
# 18.0pt;line-height:115%;font-family:"Utsaah","sans-serif"'><o:p> </o:p></span></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>और
# </span><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></p>
# <p class="MsoNormal" style="margin-top:0in;margin-right:.5in;margin-bottom:10.0pt;
# margin-left:.5in;text-align:justify;tab-stops:1.0in"><span style='font-size:
# 18.0pt;line-height:115%;font-family:"Utsaah","sans-serif"'>“ <span lang="HI">कि
# अनुदानों की अनुपूरक
# मांगों की सूची
# के स्तम्भ</span> 2 <span lang="HI">में दर्शाये
# गए मांग शीर्ष
# संख्या</span> 1,2,4,5, 7 <span lang="HI">से</span>
# 9,<span style="mso-spacerun:yes">  </span>14 <span lang="HI">से</span>
# 16,<span style="mso-spacerun:yes">  </span>18, 20, 23 <span lang="HI">से</span>
# 27, 29, 32, 34, 39 <span lang="HI">से</span> 44, 48, 51 <span lang="HI">से</span> 53, 57, 59, 61, 63, 65, 67, 70, 71, 73, 75, 76,
# 83 <span lang="HI">से</span> 88, 92, 94, 95, 97, 98, 100 <span lang="HI">और</span> 101 <span lang="HI">के संबंध
# में</span> 31 <span lang="HI">मार्च</span>,
# 2021 <span lang="HI">को समाप्त होने
# वाले वर्ष में
# संदाय के दौरान
# होने वाले खर्चों
# की अदायगी करने
# हेतु अनुदानों
# की अनुपूरक मांगों
# की सूची के स्तम्भ</span>
# 3 <span lang="HI">में दर्शायी
# गई राजस्व लेखा
# तथा पूंजी लेखा
# संबंधी राशियों
# से अनधिक<span style="mso-spacerun:yes">  </span>संबंधित<span style="mso-spacerun:yes">  </span>अनुपूरक
# राशियां भारत की
# संचित निधि में
# से राष्ट्रपति
# को दी जाएं ।</span> ”<o:p></o:p></span></p>
# <b><span lang="HI" style='font-size:18.0pt;line-height:115%;font-family:"Utsaah","sans-serif";
# mso-fareast-font-family:Calibri;mso-fareast-theme-font:minor-latin;mso-ansi-language:
# EN-US;mso-fareast-language:EN-US;mso-bidi-language:HI'><br clear="all" style="mso-special-character:line-break;page-break-before:always"/>
# </span></b>
# <p class="MsoNormal"><b><span style='font-size:18.0pt;line-height:115%;
# font-family:"Utsaah","sans-serif"'><o:p> </o:p></span></b></p>
# </a><p class="MsoNormal"><a name="3901*1"></a><a name="_GoBack"></a><b><span style='font-size:18.0pt;
# line-height:115%;font-family:"Utsaah","sans-serif";mso-no-proof:yes'><v:shape id="image1.png" o:spid="_x0000_i1026" style="width:468pt;
#  height:661.5pt;visibility:visible;mso-wrap-style:square" type="#_x0000_t75">
# <v:imagedata o:title="" src="18092020_files/image002.png">
# </v:imagedata></v:shape></span></b><b><span style='font-size:18.0pt;line-height:115%;
# font-family:"Utsaah","sans-serif"'><o:p></o:p></span></b></p>
# <p class="MsoNormal"><b><span style='font-size:18.0pt;line-height:115%;
# font-family:"Utsaah","sans-serif";mso-no-proof:yes'><v:shape id="image2.png" o:spid="_x0000_i1025" style="width:468pt;height:661.5pt;
#  visibility:visible;mso-wrap-style:square" type="#_x0000_t75">
# <v:imagedata o:title="" src="18092020_files/image003.png">
# </v:imagedata></v:shape></span></b><b><span style='font-size:18.0pt;line-height:115%;
# font-family:"Utsaah","sans-serif"'><o:p></o:p></span></b></p>
# <p class="MsoNormal" style="line-height:150%"><b><span lang="HI" style='font-size:
# 18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>माननीय</span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'> <b>सभापति</b></span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>:<span style="mso-spacerun:yes">
# </span></span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;
# font-family:"Utsaah","sans-serif";mso-ansi-font-weight:bold'>श्री
# अधीर रंजन चौधरी
# जी <o:p></o:p></span></p>
# <p class="MsoNormal" style="text-align:justify;line-height:150%"><b><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>SHRI
# ADHIR RANJAN CHOWDHURY (BAHARAMPUR):</span></b><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'> Madam, the House is not in
# order.<span style="mso-spacerun:yes">  </span>Kindly bring the House in order
# …(<i style="mso-bidi-font-style:normal">Interruptions</i>). <span lang="HI">नहीं</span>,
# <span lang="HI">ऐसे कैसे हो
# सकता है</span>? <span lang="HI">आप
# मंत्री जी को कहिए
# की</span> ...<a href="#_ftn11" name="_ftnref11" style="mso-footnote-id:ftn11" title=""><span class="MsoFootnoteReference"><span style="vertical-align:baseline">**</span></span></a> <span lang="HI">क्या
# अभी हमारे </span><i style="mso-bidi-font-style:normal">…<a href="#_ftn12" name="_ftnref12" style="mso-footnote-id:ftn12" title=""><span class="MsoFootnoteReference"><span style="vertical-align:baseline">*</span></span></a> </i><span lang="HI">हैं</span>?<span style="mso-spacerun:yes">  </span><span lang="HI">क्या यहां</span><span style="mso-spacerun:yes">  </span><i style="mso-bidi-font-style:normal">… * </i><span style="mso-spacerun:yes"> </span><span lang="HI">हैं</span>? <span lang="HI">सदन के अंदर इन
# लोगों के खिलाफ</span>
# ... ** <span lang="HI">होता है</span>, <span lang="HI">सदन के अंदर </span><i style="mso-bidi-font-style:normal">… * </i><span style="mso-spacerun:yes"> </span><span lang="HI">के खिलाफ</span>
# ... **<span style="mso-spacerun:yes">  </span><span lang="HI">की क्या
# जरूरत थी</span>? <span lang="HI">नहीं</span>,
# <span lang="HI">हमें बोलने का
# मौका दीजिए<span style="mso-spacerun:yes">  </span>। </span><span style="mso-spacerun:yes"> </span>(<span lang="HI">व्यवधान)
# हमारी भी मांग
# है</span>, <span lang="HI">अगर आप सदन
# चलाना नहीं चाहते
# तो अलग बात है ।
# आप हमारे पर</span> ... **
# <span lang="HI">मत किया करो</span>,
# <span lang="HI">हमारे पर</span> ...
# **<span style="mso-spacerun:yes">  </span><span lang="HI">नहीं
# करो<span style="mso-spacerun:yes">  </span>। </span><span style="mso-spacerun:yes"> </span>(<span lang="HI">व्यवधान)</span>…<span lang="HI" style="mso-ansi-font-weight:bold">माननीय
# सभापति जी</span><b style="mso-bidi-font-weight:normal">, </b><span lang="HI" style="mso-ansi-font-weight:
# bold">इन लोगों की बात
# भी सुनी जाए<span style="mso-spacerun:yes">  </span>।</span> (<span lang="HI">व्यवधान)
# अगर आप जबरदस्ती
# सदन चलाना चाहती
# हैं तो अलग बात
# है<span style="mso-spacerun:yes">  </span>। </span><span style="mso-spacerun:yes"> </span>(<span lang="HI">व्यवधान)</span><span style="mso-bidi-font-weight:bold"><o:p></o:p></span></span></p>
# <p class="MsoNormal" style="line-height:150%"><b><span lang="HI" style='font-size:
# 18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>माननीय</span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'> <b>सभापति</b></span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>: </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>माननीय अधीर
# रंजन जी</span><b style="mso-bidi-font-weight:
# normal"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>,
# </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:
# "Utsaah","sans-serif";mso-ansi-font-weight:bold'>अगर आप
# नहीं बोलेंगे तो
# मैं श्री जयंत
# सिन्हा जी को बोलने
# के लिए कहूंगी<span style="mso-spacerun:yes">  </span>।</span><b style="mso-bidi-font-weight:
# normal"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></b></p>
# <p class="MsoNormal" style="line-height:150%"><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif";mso-bidi-font-weight:bold'><span style="mso-tab-count:1">          </span></span><span lang="HI" style='font-size:
# 18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";mso-ansi-font-weight:
# bold'>श्री जयंत सिन्हा
# जी<span style="mso-spacerun:yes">  </span>।</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></b></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><span style="mso-spacerun:yes"> </span>(<span lang="HI">व्यवधान)</span><o:p></o:p></span></p>
# <span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-fareast-font-family:Calibri;mso-fareast-theme-font:minor-latin;mso-ansi-language:
# EN-US;mso-fareast-language:EN-US;mso-bidi-language:HI'><br clear="all" style="page-break-before:always"/>
# </span>
# <p class="MsoNormal" style="margin-left:4.5pt;line-height:150%"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><a name="4768*2"><b><o:p></o:p></b></a></span></p><a name="4768*2">
# <p class="MsoNormal" style="margin-bottom:0in;margin-bottom:.0001pt;text-align:
# justify;line-height:150%"><b><span lang="HI" style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>श्री जयंत
# सिन्हा</span></b><b><span style='font-size:
# 18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'> (<span lang="HI">हज़ारीबाग</span>):
# </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:
# "Utsaah","sans-serif"'>माननीय सभापति
# जी</span><span style='font-size:18.0pt;line-height:150%;font-family:
# "Utsaah","sans-serif"'>, <span lang="HI">मैं सर्वप्रथम
# आप लोगों को याद
# दिलाना चाहूंगा
# कि कल</span> 17 <span lang="HI">सितम्बर
# को हमारे यशस्वी
# प्रधान मंत्री
# जी का जन्मदिन
# था ।</span> (<span lang="HI">व्यवधान)
# इस दिन हज़ारीबाग
# के झंडा चौक और
# रामगढ़ के सुभाष
# चौक पर आम जनता
# केक बांट रही थी</span>,
# <span lang="HI">मिठाई बांट रही
# थी । आम जनता यशस्वी
# प्रधान मंत्री
# जी को अनंत शुभकामनाएं
# दे रही थी</span>, <span lang="HI">परमेश्वर
# से प्रार्थना कर
# रही थी कि वह सदैव
# स्वस्थ रहें और
# जिस प्रकार से
# उनका नेतृत्व और
# मार्गदर्शन देश
# को मिलता रहा है</span>,
# <span lang="HI">मिलता रहे ।
# जनता न सिर्फ हज़ारीबाग
# और रामगढ़ में यह
# कर रही थी</span>, <span lang="HI">बल्कि
# देश भर में माननीय
# प्रधान मंत्री
# जी को शुभकामनाएं
# दी जा रही थीं ।</span>
# (<span lang="HI">व्यवधान)</span><o:p></o:p></span></p>
# <p class="MsoNormal" style="margin-bottom:0in;margin-bottom:.0001pt;text-align:
# justify;line-height:150%"><span style='font-size:18.0pt;line-height:150%;
# font-family:"Utsaah","sans-serif"'><span style="mso-tab-count:1">          </span><span lang="HI">महोदया</span>, <span lang="HI">आपको
# मालूम है और हम
# सबको भी मालूम
# है कि आज किस गंभीर
# परिस्थिति से देश
# गुज़र रहा है । पूरे
# विश्व में कोविड
# का एक तूफान चल
# रहा है । हम कोविड
# की महामारी से
# त्रस्त हैं । हम
# जब इस तूफान से
# गुज़र रहे हैं</span>,
# <span lang="HI">अगर आप विश्व
# भर में देखें</span>,
# <span lang="HI">सब देशों का
# मुआइना करें तो
# हमें नज़र आता है
# कि हम </span><span style="mso-spacerun:yes"> </span>(<span lang="HI">व्यवधान)</span><span style="mso-bidi-font-weight:bold"><o:p></o:p></span></span></p>
# <p class="MsoNormal" style="text-align:justify;line-height:150%"><b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>माननीय
# सभापति</span></b><b><span style='font-size:
# 18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>:</span></b><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'> <span lang="HI">सभा की कार्यवाही
# पांच बजे तक के
# लिए स्थगित होती
# है ।</span><o:p></o:p></span></p>
# <p class="MsoNormal" style="line-height:150%"><b><u><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'>16.27 hrs<o:p></o:p></span></u></b></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><i><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>The
# Lok Sabha then adjourned till Seventeen of the clock.<o:p></o:p></span></i></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><o:p> </o:p></span></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><v:shape id="_x0000_s1031" o:connectortype="straight" style="position:absolute;left:0;
#  text-align:left;margin-left:201.75pt;margin-top:5.6pt;width:90pt;height:0;
#  z-index:5" type="#_x0000_t32"><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'><o:p> </o:p></span></v:shape></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><u><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><o:p><span style="text-decoration:none"> </span></o:p></span></u></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><u><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><o:p><span style="text-decoration:none"> </span></o:p></span></u></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><u><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><o:p><span style="text-decoration:none"> </span></o:p></span></u></p>
# <br clear="ALL" style="mso-ignore:vglayout"/>
# <p class="MsoNormal" style="line-height:150%"><b><u><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'>17.01 hrs<o:p></o:p></span></u></b></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><i><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>The
# Lok Sabha reassembled at One Minute past Seventeen of the Clock. <o:p></o:p></span></i></p>
# <p class="MsoNormal" style="line-height:150%"><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif";color:#C00000'><span style="mso-tab-count:3">                             </span></span><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><span style="mso-tab-count:1">          </span>( Shrimati Rama Devi <i>in the Chair</i>)<u><o:p></o:p></u></span></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><span style="mso-spacerun:yes"> </span>(<span lang="HI">व्यवधान)</span><o:p></o:p></span></p>
# <p class="MsoNormal" style="line-height:150%"><b><span lang="HI" style='font-size:
# 18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>माननीय</span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'> <b>सभापति</b></span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>: </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>आप पहले बैठ
# जाइए<span style="mso-spacerun:yes">  </span>। </span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></b></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><span style="mso-spacerun:yes"> </span>(<span lang="HI">व्यवधान)</span><o:p></o:p></span></p>
# <p class="MsoNormal" style="text-align:justify;line-height:150%"><b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>माननीय
# सभापति</span></b><b><span style='font-size:
# 18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>: </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>आप
# सभी अपनी सीट पर
# बैठ जाइए<span style="mso-spacerun:yes">  </span>।</span><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></p>
# ...
# । इसका पूरा सॉल्यूशन
# काउंसिल में आएगा
# । यह मेरा स्ट्रांग
# ऑप्टिमिस्टिक
# व्यू है । हम काउंसिल
# में तय करेंगे
# कि कैसे करना है
# ।</span><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>
# The Centre is not reneging, not at all thinking about it. People have put their
# words in my mouth saying: ‘Is Centre reneging?’. Sir, I want to say here,
# through you, that the Centre is not reneging. <span lang="HI">जब मैं
# पूरे के पूरे ग्रॉस
# रेवेन्यू डिवॉल्व
# कर रही हूं</span>, <span lang="HI">अगर सेस में कुछ
# होता तो वह आपको
# दे देते । अगर</span>,
# <span lang="HI">सेस में नहीं
# है</span>, <span lang="HI">फिर कानूनन
# जो होना चाहिए
# वह जीएसटी काउंसिल
# में होगा । वे जो
# भी तय करेंगे</span>,
# <span lang="HI">वह हमें मंजूर
# होगा । </span>So, Supplementary Demands for
# Grants</span></a><a name="_Hlk51405405"> </a><span lang="HI">के विषय
# में जहां तक जवाब
# देना था</span>, probably I have responded. <span lang="HI">उसके अलावा जो
# भी विषय उठाया
# गया</span>, <span lang="HI">उसका भी
# मैंने जवाब दिया
# है ।</span><o:p></o:p></p>
# <p class="MsoNormal" style="text-align:justify;text-indent:.5in;line-height:150%"><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>मैं
# आपके माध्यम से
# सभी माननीय सदस्यों
# से अपील करती हूं
# कि आप सप्लिमेंटरी
# डिमांड फॉर ग्रांट्स
# को पारित करें
# । आपने सुना कि
# मनरेगा सहित जनता
# के लिए जितने उपयोगी
# कार्यक्रम हैं</span><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>, <span lang="HI">उनके लिए सब्स्टैंशियल
# एलोकेशन इसमें
# आ रही है । अभी तक
# विपक्ष के द्वारा
# हमें जो सुनाई
# दिया कि खर्च करो</span>,
# <span lang="HI">खर्च करो तो
# खर्च के लिए पैसा
# है । आप इसको क्लियर
# कीजिए । </span><o:p></o:p></span></p>
# <p class="MsoNormal" style="text-align:justify;text-indent:.5in;line-height:150%"><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>धन्यवाद
# ।</span><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></p>
# <p class="MsoNormal" style="line-height:150%"><b><span lang="HI" style='font-size:
# 18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>माननीय</span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'> <b>अध्यक्ष</b></span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>: </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>अब मैं </span><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-bidi-font-weight:bold'>2020-2021</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'> </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>के लिए अनुदानों
# की अनुपूरक मांगें</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>-</span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>पहला बैच सभा
# के मतदान के लिए
# रखता हूं ।</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></b></p>
# <p class="MsoNormal" style="text-indent:.5in;line-height:150%"><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>प्रश्न यह
# है</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>:<o:p></o:p></span></b></p>
# <p class="MsoNormal" style="margin-top:0in;margin-right:.5in;margin-bottom:0in;
# margin-left:.5in;margin-bottom:.0001pt;text-align:justify;line-height:normal;
# tab-stops:1.0in"><span style='font-size:18.0pt;font-family:"Utsaah","sans-serif"'>“<span lang="HI">कि<span style="mso-spacerun:yes">  </span>अनुदानों<span style="mso-spacerun:yes">  </span>की<span style="mso-spacerun:yes">  </span>अनुपूरक
# मांगों की सूची
# के स्तम्भ</span> 2 <span lang="HI">में दर्शाये
# गए मांग शीर्ष
# संख्या</span> 1, 2, 4, 5, 7 <span lang="HI">से</span>
# 9, 14 <span lang="HI">से</span> 16, 18, 20, 23 <span lang="HI">से</span>
# 27, 29, 32, 34, 39 <span lang="HI">से</span> 44, 48, 51 <span lang="HI">से</span> 53, 57, 59, 61, 63, 65, 67, 70, 71, 73, 75, 76,
# 83 <span lang="HI">से</span> 88, 92, 94, 95, 97, 98, 100 <span lang="HI">और</span> 101 <span lang="HI">के संबंध
# में</span>, 31 <span lang="HI">मार्च</span>
# 2021 <span lang="HI">को समाप्त होने
# वाले वर्ष में
# संदाय<span style="mso-spacerun:yes">  </span>के<span style="mso-spacerun:yes">  </span>दौरान<span style="mso-spacerun:yes">  </span>होने<span style="mso-spacerun:yes">  </span>वाले खर्चों
# की अदायगी करने
# हेतु अनुदानों
# की अनुपूरक मांगों
# की सूची के स्तम्भ</span>
# 3<span style="mso-spacerun:yes">  </span><span lang="HI">में<span style="mso-spacerun:yes">  </span>दर्शायी<span style="mso-spacerun:yes">  </span>गयी<span style="mso-spacerun:yes">  </span>राजस्व लेखा
# तथा पूँजी लेखा
# संबंधी राशियों
# से अनधिक संबंधित
# अनुपूरक राशियां
# भारत की संचित
# निधि में से राष्ट्रपति
# को दी जाएं ।</span><span style="mso-spacerun:yes">  </span>”<o:p></o:p></span></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><u><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>प्रस्ताव
# स्वीकृत हुआ ।</span></u><b style="mso-bidi-font-weight:normal"><u><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></u></b></p>
# <p class="MsoNormal" style="line-height:150%"><b><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'><o:p> </o:p></span></b></p>
# <p class="MsoNormal" style="line-height:150%"><b><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'><o:p> </o:p></span></b></p>
# <p class="MsoNormal" style="line-height:150%"><b><span lang="HI" style='font-size:
# 18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>माननीय</span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'> <b>अध्यक्ष</b></span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'>: </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>अब मैं </span><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-bidi-font-weight:bold'>2016-2017</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'> </span></b><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>के लिए सिविल
# मंत्रालयों से
# संबंधित अनुदानों
# की अतिरिक्त मांगें
# सभा के मतदान के
# लिए रखता हूं ।</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:
# 150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></b></p>
# <p class="MsoNormal" style="text-indent:.5in;line-height:150%"><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>प्रश्न यह
# है</span><b style="mso-bidi-font-weight:normal"><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>:<o:p></o:p></span></b></p>
# <p class="MsoNormal" style="margin-top:0in;margin-right:.5in;margin-bottom:10.0pt;
# margin-left:.5in;text-align:justify;line-height:normal;tab-stops:1.0in"><span style='font-size:18.0pt;font-family:"Utsaah","sans-serif"'>“<span lang="HI">कि
# सिविल मंत्रालयों
# से संबंधित अनुदानों
# की अतिरिक्त मांगों
# की सूची के स्तम्भ</span>
# 2 <span lang="HI">में दर्शाए
# गए मांग शीर्ष
# संख्या</span> 13, 21 <span lang="HI">और</span>
# 23 <span lang="HI">के संबंध में</span>
# 31 <span lang="HI">मार्च</span>, 2017 <span lang="HI">को समाप्त होने
# वाले वर्ष में
# संदाय के दौरान
# हुए खर्चों की
# अदायगी करने हेतु
# अनुदानों की अतिरिक्त
# मांगों की सूची
# के स्तम्भ</span> 3 <span lang="HI">में दर्शायी
# गयी राजस्व लेखा
# तथा पूँजी लेखा
# संबंधी राशियों
# से अनधिक संबंधित
# अतिरिक्त राशियां
# भारत की संचित
# निधि में से राष्ट्रपति
# को दी जाएं ।</span><span style="mso-spacerun:yes">  </span>”<o:p></o:p></span></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><u><span lang="HI" style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif";
# mso-ansi-font-weight:bold'>प्रस्ताव
# स्वीकृत हुआ ।</span></u><b style="mso-bidi-font-weight:normal"><u><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'><o:p></o:p></span></u></b></p>
# <p align="center" class="MsoNormal" style="text-align:center;line-height:150%"><o:wrapblock><v:shape id="_x0000_s1033" o:connectortype="straight" style="position:absolute;left:0;
#   text-align:left;margin-left:199.5pt;margin-top:23.5pt;width:91.9pt;height:0;
#   z-index:7" type="#_x0000_t32">
# </v:shape></o:wrapblock><u><span style='font-size:18.0pt;line-height:150%;font-family:
# "Utsaah","sans-serif";mso-bidi-font-weight:bold'><o:p><span style="text-decoration:
#  none"> </span></o:p></span></u></p>
# <p class="MsoNormal" style="text-align:justify;line-height:150%"><b><u><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'><o:p><span style="text-decoration:none"> </span></o:p></span></u></b></p>
# <b><u><span style='font-size:18.0pt;line-height:115%;font-family:"Utsaah","sans-serif";
# mso-fareast-font-family:Calibri;mso-fareast-theme-font:minor-latin;mso-ansi-language:
# EN-US;mso-fareast-language:EN-US;mso-bidi-language:HI'><br clear="all" style="mso-special-character:line-break;page-break-before:always"/>
# </span></u></b>
# <p class="MsoNormal"><b><u><span style='font-size:18.0pt;line-height:115%;
# font-family:"Utsaah","sans-serif"'><o:p><span style="text-decoration:none"> </span></o:p></span></u></b></p>
# <br clear="ALL" style="mso-ignore:vglayout"/>
# <p class="MsoNormal" style="text-align:justify;line-height:150%"><b><u><span style='font-size:18.0pt;line-height:150%;font-family:"Utsaah","sans-serif"'>22.30
# hrs</span></u></b><b><span style='font-size:18.0pt;line-height:150%;font-family:
# "Utsaah","sans-serif"'><span style="mso-spacerun:yes">
# </span><o:p></o:p></span></b></p>
# <p class="MsoNormal" style="line-height:150%"><span style='font-size:18.0pt;
# line-height:150%;font-family:"Utsaah","sans-serif"'>
# </span></p></td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# </tbody></table>
# </div>
# </div>
# </div>
# <!-- /left_mid_right_block -->
# </div>
# <div class="clear">
# </div>
# <!-- Footer -->
# <style type="text/css">
#     p.devlpBy
#     {
#         font-size: 1.2em;
#         color: #000;
#         text-align: center;
#         margin-top: 15px;
#     }
# </style>
# <div>
# <p class="devlpBy">
#         Developed and Hosted by <strong>National Informatics Centre (NIC)</strong>
# <br/>
# <span style="color: #9F382A; font-weight: bold;">Content on this website is published,
#             managed &amp; maintained by Software Unit, Computer (HW &amp; SW) Management. Branch,
#             Lok Sabha Secretariat</span></p>
# </div>
# <div class="footer">
# <div class="wrapper">
# <div class="footLinkPan">
# <ul>
# <li><a href="http://loksabha.nic.in" title="Home">Home</a></li><li><a href="http://loksabhaph.nic.in/Members/MemberHomepage.aspx" title="Members">Members</a></li><li><a href="http://loksabhaph.nic.in/Business/ListofBusiness.aspx" title="Business">Business</a></li><li><a href="http://loksabhaph.nic.in/Questions/QuestionsHome.aspx" title="Questions">Questions</a></li><li><a href="http://loksabhaph.nic.in/Debates/debates.aspx" title="Debates">Debates</a></li><li><a href="http://loksabhaph.nic.in/PapersLaid/SearchPaperslaid.aspx" laid="" title="Papers">Papers Laid</a></li>
# </ul>
# <ul>
# <li><a href="http://loksabhaph.nic.in/Legislation/NewAdvsearch.aspx" title="Legislation">Legislation</a></li><li><a href="http://loksabhaph.nic.in/Committee/CommitteeHome.aspx" title="Committees">Committees</a></li><li><a href="https://loksabhatv.nic.in/" title="LS" tv="">LS TV</a></li><li><a href="http://loksabhadocs.nic.in/intranet/lslogin.aspx" title="Intranet">Intranet</a></li><li><a href="http://loksabhaph.nic.in/Secretariat/OfficersOfSecretariat.aspx" title="Secretariat">Secretariat</a></li><li><a href="http://bpst.nic.in/" title="PRIDE">PRIDE</a></li>
# </ul>
# <ul>
# <li><a href="http://loksabhaph.nic.in/Recruitment/advandnot.aspx" title="Recruitment">Recruitment</a></li><li><a href="http://loksabhaph.nic.in/SCST/SCST_Reservation.aspx" reservation="" title="SC/ST">SC/ST Reservation</a></li><li><a href="http://loksabhaph.nic.in/ConferenceLinks.aspx" title="Conference">Conference</a></li><li><a href="http://parliamentlibraryindia.nic.in/" library="" title="Parliament">Parliament Library</a></li><li><a href="http://parliamentmuseum.org/indextry.html" museum="" title="Parliament">Parliament Museum</a></li>
# </ul>
# <ul>
# <li><a href="http://loksabhaph.nic.in/Parliament.aspx" parliament="" title="About">About Parliament</a></li><li><a gallery="" href="http://loksabhaph.nic.in/PhotoGal/ViewAllPhotoCategory.aspx" title="Photo">Photo Gallery</a></li><li><a href="http://loksabhaph.nic.in/Index.aspx" links="" title="Related">Related Links</a></li><li><a href="http://loksabhaph.nic.in/RTI/RTIHome.aspx" title="RTI">RTI</a></li><li><a href="http://loksabhaph.nic.in/Tender.aspx" title="Tenders">Tenders</a></li><li><a href="http://loksabhaph.nic.in/FAQ.aspx" title="FAQ">FAQ</a></li>
# </ul>
# <ul>
# <li><a href="http://speakerloksabha.nic.in/biography.asp" title="Speaker">Speaker</a></li><li><a href="http://loksabhaph.nic.in/writereaddata/DS/Deputy_speaker.html" speaker="" title="Dy.">Dy. Speaker</a></li><li><a house="" href="http://loksabhaph.nic.in/Members/MemberBioprofile.aspx?mpsno=4589" of="" the="" title="Leader">Leader of the House</a></li><li><a chairpersons="" href="http://loksabhaph.nic.in/writereaddata/Members/panel_chairmen.pdf" of="" title="Panel">Panel of Chairpersons</a></li><li><a href="http://loksabhaph.nic.in/Webinformation.aspx" title="Contact" us="">Contact Us</a></li><li><a href="http://loksabhaph.nic.in/AddFeedback.aspx" title="Feedback">Feedback</a></li>
# </ul>
# <ul>
# <li><a href="http://cabsec.nic.in/showpdf.php?type=council_cabinet_cabinetministers" ministers="" of="" title="Council">Council of Ministers</a></li><li><a href="http://loksabhaph.nic.in/pub_ministry.aspx" ministries="" of="" title="Publications">Publications of Ministries</a></li><li><a href="http://loksabhaph.nic.in/ParliamentProcedureList.aspx" procedures="" title="Parliamentry">Parliamentry Procedures</a></li><li><a href="http://loksabhaph.nic.in/JournalParliament.aspx" information="" of="" parliamentary="" title="Journal">Journal of Parliamentary Information</a></li>
# <li style="color: White;"><strong>Visitor's Counter:</strong>83992101</li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footBtmStrip">
# <div class="wrapper">
# <ul>
# <li><a href="../Copyright.aspx?linkid=1" title="Copyright">Copyright</a></li>
# <li><a href="../PrivacyPolicy.aspx?linkid=2" title="Privacy Policy">Privacy Policy</a></li>
# <li><a href="../Disclaimer.aspx?linkid=3" title="Disclaimer">Disclaimer</a></li>
# <li><a href="../TermsConditions.aspx?linkid=4" title="Terms &amp; Conditions">Terms &amp;
#                 Conditions</a></li>
# <li><a href="../AccessibilityStatement.aspx?linkid=5" title="Accessibility Statement">
#                 Accessibility Statement</a></li>
# <li><a href="../AccessibilityOptions.aspx?linkid=6" title="Accessibility Options">Accessibility
#                 Options</a></li>
# <li><a href="../AddFeedback.aspx" title="Feedback">Feedback</a></li>
# <li><a href="../Sitemap.aspx" title="Site Map">Site Map</a></li>
# </ul>
# </div>
# </div>
# <!-- /Footer -->
# </form>
# </body></html>

# %% [markdown]
# First we'll get all the rows of the table using the `td` selector.table

# %%
#Since debate_Text is present inside the <p> tag.Lets select p tag
all_text=""
debates=debate_text.find_all('p')
for j in debates:
    jnew=j.getText().strip()
    all_text=all_text+jnew

# %%
all_text
# Out:
# 'India Time \n\n\nYour Time \n\n\n                        Wednesday,\n                        27 January 2021Title:\n Combined discussion on the Supplementary Demands for Grant \'First Batch \'\n2020-21 and Demands for excess Grants (2016-17).माननीय सभापति: मद संख्या\n16 और 17\xa0\nअब सभा\nमें अनुदानों की अनुपूरक\nमांगों तथा अतिरिक्त\nअनुदानों की मांगों\nको एक साथ चर्चा\nके लिए लिया जाएगा\n। अनुपूरक मांगों\nपर प्रो.\nसौगत राय\nजी के चार कटौती\nप्रस्ताव परिचालित\nकिए गए हैं ।(व्यवधान)माननीय सभापति: यदि\nवह अपने कटौती\nप्रस्ताव प्रस्तुत\nकरना चाहते हैं\nतो पन्द्रह मिनट\nके भीतर सभा पटल\nपर पर्ची भेज दें, जिसमें उन कटौती\nप्रस्तावों की\nसंख्याएं लिखी\nहों जिन्हें वह\nप्रस्तुत करना\nचाहते हैं ।इस\nप्रकार प्रस्तुत\nकिए गए कटौती प्रस्ताव\nकी क्रम संख्याओं\nको दर्शाने वाली\nसूची कुछ समय के\nपश्चात् सूचना\nपट्ट पर लगा दी\nजाएगी ।(व्यवधान)माननीय सभापति: यदि\nमाननीय सदस्यों\nको उस सूची में\nकोई विसंगति मिले\nतो वह उसकी सूचना\nतत्काल सभा पटल\nपर मौजूद अधिकारी\nको दे दें ।(व्यवधान)माननीय सभापति: प्रस्ताव\nप्रस्तुत हुए:“ कि\nसिविल मंत्रालयों\nसे संबंधित अनुदानों\nकी अतिरिक्त मांगों\nकी सूची के स्तम्भ\n2 में दर्शाए\nगए मांग शीर्ष\nसंख्या 13, 21 और\n23 के संबंध में\n31 मार्च, 2017 को समाप्त होने\nवाले वर्ष में\nसंदाय के दौरान\nहुए खर्चों की\nअदायगी करने हेतु\nअनुदानों की अतिरिक्त\nमांगों की सूची\nके स्तंभ 3 में\nदर्शायी गयी राजस्व\nलेखा तथा पूंजी\nलेखा संबंधी राशियों\nसे अनधिक संबंधित\nअतिरिक्त राशियां\nभारत की संचित\nनिधि में से राष्ट्रपति\nको दी जाएं । ”और“ कि\nअनुदानों की अनुपूरक\nमांगों की सूची\nके स्तम्भ 2 में दर्शाये\nगए मांग शीर्ष\nसंख्या 1,2,4,5, 7 से\n9,\xa0 14 से\n16,\xa0 18, 20, 23 से\n27, 29, 32, 34, 39 से 44, 48, 51 से 53, 57, 59, 61, 63, 65, 67, 70, 71, 73, 75, 76,\n83 से 88, 92, 94, 95, 97, 98, 100 और 101 के संबंध\nमें 31 मार्च,\n2021 को समाप्त होने\nवाले वर्ष में\nसंदाय के दौरान\nहोने वाले खर्चों\nकी अदायगी करने\nहेतु अनुदानों\nकी अनुपूरक मांगों\nकी सूची के स्तम्भ\n3 में दर्शायी\nगई राजस्व लेखा\nतथा पूंजी लेखा\nसंबंधी राशियों\nसे अनधिक\xa0 संबंधित\xa0 अनुपूरक\nराशियां भारत की\nसंचित निधि में\nसे राष्ट्रपति\nको दी जाएं । ”माननीय सभापति:\xa0\nश्री\nअधीर रंजन चौधरी\nजीSHRI\nADHIR RANJAN CHOWDHURY (BAHARAMPUR): Madam, the House is not in\norder.\xa0 Kindly bring the House in order\n…(Interruptions). नहीं,\nऐसे कैसे हो\nसकता है? आप\nमंत्री जी को कहिए\nकी ...** क्या\nअभी हमारे …* हैं?\xa0 क्या यहां\xa0 … * \xa0हैं? सदन के अंदर इन\nलोगों के खिलाफ\n... ** होता है, सदन के अंदर … * \xa0के खिलाफ\n... **\xa0 की क्या\nजरूरत थी? नहीं,\nहमें बोलने का\nमौका दीजिए\xa0 । \xa0(व्यवधान)\nहमारी भी मांग\nहै, अगर आप सदन\nचलाना नहीं चाहते\nतो अलग बात है ।\nआप हमारे पर ... **\nमत किया करो,\nहमारे पर ...\n**\xa0 नहीं\nकरो\xa0 । \xa0(व्यवधान)…माननीय\nसभापति जी, इन लोगों की बात\nभी सुनी जाए\xa0 । (व्यवधान)\nअगर आप जबरदस्ती\nसदन चलाना चाहती\nहैं तो अलग बात\nहै\xa0 । \xa0(व्यवधान)माननीय सभापति: माननीय अधीर\nरंजन जी,\nअगर आप\nनहीं बोलेंगे तो\nमैं श्री जयंत\nसिन्हा जी को बोलने\nके लिए कहूंगी\xa0 ।श्री जयंत सिन्हा\nजी\xa0 ।(व्यवधान)श्री जयंत\nसिन्हा (हज़ारीबाग):\nमाननीय सभापति\nजी, मैं सर्वप्रथम\nआप लोगों को याद\nदिलाना चाहूंगा\nकि कल 17 सितम्बर\nको हमारे यशस्वी\nप्रधान मंत्री\nजी का जन्मदिन\nथा । (व्यवधान)\nइस दिन हज़ारीबाग\nके झंडा चौक और\nरामगढ़ के सुभाष\nचौक पर आम जनता\nकेक बांट रही थी,\nमिठाई बांट रही\nथी । आम जनता यशस्वी\nप्रधान मंत्री\nजी को अनंत शुभकामनाएं\nदे रही थी, परमेश्वर\nसे प्रार्थना कर\nरही थी कि वह सदैव\nस्वस्थ रहें और\nजिस प्रकार से\nउनका नेतृत्व और\nमार्गदर्शन देश\nको मिलता रहा है,\nमिलता रहे ।\nजनता न सिर्फ हज़ारीबाग\nऔर रामगढ़ में यह\nकर रही थी, बल्कि\nदेश भर में माननीय\nप्रधान मंत्री\nजी को शुभकामनाएं\nदी जा रही थीं ।\n(व्यवधान)महोदया, आपको\nमालूम है और हम\nसबको भी मालूम\nहै कि आज किस गंभीर\nपरिस्थिति से देश\nगुज़र रहा है । पूरे\nविश्व में कोविड\nका एक तूफान चल\nरहा है । हम कोविड\nकी महामारी से\nत्रस्त हैं । हम\nजब इस तूफान से\nगुज़र रहे हैं,\nअगर आप विश्व\nभर में देखें,\nसब देशों का\nमुआइना करें तो\nहमें नज़र आता है\nकि हम \xa0(व्यवधान)माननीय\nसभापति: सभा की कार्यवाही\nपांच बजे तक के\nलिए स्थगित होती\nहै ।16.27 hrsThe\nLok Sabha then adjourn ...

# %% [markdown]
# ### Challenge 1: Now print the text of second debate present in that page
